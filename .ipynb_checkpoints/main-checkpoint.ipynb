# %% [markdown]
# <a href="https://colab.research.google.com/github/crypt0d1v3r/CannyValley/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies for pulling datasets
# %pip install kagglehub
# %pip install datasets
# %pip install torch
# %pip install torchvision
# %pip install numpy
# %pip install matplotlib
# Out:
# Requirement already satisfied: kagglehub in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from kagglehub) (0.1.15)
# Requirement already satisfied: packaging in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from requests->kagglehub) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: datasets in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: filelock in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (2.3.5)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (1.8.0)
# Requirement already satisfied: packaging in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.10.0)
# Requirement already satisfied: certifi in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.2)
# Requirement already satisfied: typer in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.17.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (0.25.0)
# Requirement already satisfied: numpy in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: torch==2.10.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torchvision) (2.10.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: filelock in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from torch==2.10.0->torchvision) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from sympy>=1.13.3->torch==2.10.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from jinja2->torch==2.10.0->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\crypt0-d1v3r\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
from datasets import load_dataset
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torchvision
from torch.utils.data import DataLoader
import torch
import os
import numpy as np
import matplotlib.pyplot as plt

class CNN(torch.nn.Module):
  def __init__(self):
      super().__init__()
      self.model = torch.nn.Sequential(
          torch.nn.Conv2d(in_channels=3, out_channels=32,
                          kernel_size=3, padding=1),
          torch.nn.ReLU(),
          torch.nn.MaxPool2d(kernel_size=2),
          torch.nn.Conv2d(in_channels=32, out_channels=64,
                          kernel_size=3, padding=1),
          torch.nn.ReLU(),
          torch.nn.MaxPool2d(kernel_size=2),
          torch.nn.Conv2d(in_channels=64, out_channels=64,
                          kernel_size=3, padding=1),
          torch.nn.ReLU(),
          torch.nn.MaxPool2d(kernel_size=2),
          torch.nn.Flatten(),
          torch.nn.Linear(64 * 28 * 28, 512),
          torch.nn.ReLU(),
          torch.nn.Linear(512, 2)
      )

  def forward(self, x):
      return self.model(x)

# %%
dataset_source = "tristanzhang32/ai-generated-images-vs-real-images"
if dataset_source == "birdy654/cifake-real-and-ai-generated-synthetic-images":
    dataset_path = kagglehub.dataset_download("birdy654/cifake-real-and-ai-generated-synthetic-images")
elif dataset_source == "Hemg/AI-vs-Real-images":
    dataset_path = load_dataset("Hemg/AI-vs-Real-images")
elif dataset_source == "bitmind/AI-vs-Real-Dataset-Images-Proper":
    dataset_path = load_dataset("bitmind/AI-vs-Real-Dataset-Images-Proper")
elif dataset_source == "tristanzhang32/ai-generated-images-vs-real-images":
    dataset_path = kagglehub.dataset_download("tristanzhang32/ai-generated-images-vs-real-images")
else:
    raise Exception(f"Dataset Source {dataset_source} Unknown")

# %% [markdown]
# Can choose from the following datasets
#
# ---
#
#
#
# *   birdy654/cifake-real-and-ai-generated-synthetic-images
# *   Hemg/AI-vs-Real-images
# *   bitmind/AI-vs-Real-Dataset-Images-Proper

# %%
data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Walk the downloaded path to find the actual train/test directories
train_dir = None
test_dir = None
for root, dirs, _ in os.walk(dataset_path):
    if 'train' in dirs:
        train_dir = os.path.join(root, 'train')
    if 'test' in dirs:
        test_dir = os.path.join(root, 'test')
    if train_dir and test_dir:
        break

train_dataset = datasets.ImageFolder(root=train_dir, transform=data_transforms)
test_dataset = datasets.ImageFolder(root=test_dir, transform=data_transforms)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Get class names
class_names = train_dataset.classes
print(f"Classes: {class_names}")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
model = CNN().to(device)
# Out:
# Classes: ['fake', 'real']
# Using device: cpu

# %%
num_epochs = 10
learning_rate = 0.001
weight_decay = 0.01
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=learning_rate, weight_decay=weight_decay)

train_loss_list = []
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}:', end=' ')
    train_loss = 0
    model.train()
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss_list.append(train_loss / len(train_loader))
    print(f"Training loss = {train_loss_list[-1]}")

plt.plot(range(1, num_epochs + 1), train_loss_list)
plt.xlabel("Number of epochs")
plt.ylabel("Training loss")
plt.show()

test_acc = 0
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        y_true = labels.to(device)
        outputs = model(images)
        _, y_pred = torch.max(outputs.data, 1)
        test_acc += (y_pred == y_true).sum().item()

print(f"Test set accuracy = {100 * test_acc / len(test_dataset)} %")

num_images = 5
y_true_name = [class_names[y_true[idx]] for idx in range(num_images)]
y_pred_name = [class_names[y_pred[idx]] for idx in range(num_images)]
title = f"Actual labels: {y_true_name}, Predicted labels: {y_pred_name}"

plt.imshow(np.transpose(torchvision.utils.make_grid(images[:num_images].cpu(), normalize=True, padding=1).numpy(), (1, 2, 0)))
plt.title(title)
plt.axis("off")
plt.show()
torch.save(model.state_dict(), 'tristanzhang32.pth')
# Out:
# Epoch 1/10:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 19
#      17 loss = criterion(outputs, labels)
#      18 optimizer.zero_grad()
# ---> 19 loss.backward()
#      20 optimizer.step()
#      21 train_loss += loss.item()
#
# File ~\anaconda3\Lib\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~\anaconda3\Lib\site-packages\torch\autograd\__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File ~\anaconda3\Lib\site-packages\torch\autograd\graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:
